# %%
import pandas as pd
import numpy as np
autos = pd.read_csv('autos.csv',encoding='Latin-1')

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename({'yearOfRegistration':'registration_year','monthOfRegistration':'registration_month',
             'notRepairedDamage':'unrepaired_damage','dateCreated':'ad_created'},axis=1, inplace=True)

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  registration_year  \
# 0  privat   Angebot  $5,000  control         bus               2004
# 1  privat   Angebot  $8,500  control   limousine               1997
# 2  privat   Angebot  $8,990     test   limousine               2009
# 3  privat   Angebot  $4,350  control  kleinwagen               2007
# 4  privat   Angebot  $1,350     test       kombi               2003
#
#      gearbox  powerPS   model   odometer  registration_month fuelType  \
# ...

# %%
autos.describe()
# Out:
#        registration_year       powerPS  registration_month  nrOfPictures  \
# count       50000.000000  50000.000000        50000.000000       50000.0
# mean         2005.073280    116.355920            5.723360           0.0
# std           105.712813    209.216627            3.711984           0.0
# min          1000.000000      0.000000            0.000000           0.0
# 25%          1999.000000     70.000000            3.000000           0.0
# 50%          2003.000000    105.000000            6.000000           0.0
# 75%          2008.000000    150.000000            9.000000           0.0
# max          9999.000000  17700.000000           12.000000           0.0
#
#          postalCode
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %%
autos['odometer'] = autos['odometer'].str.replace('km','').str.replace(',','').astype(int)

# %%
autos['price'] = autos['price'].str.replace('$','').str.replace(',','').astype(float)

# %%
autos.rename({'odometer':'odometer_km'},inplace=True,axis=1)

# %%
autos.describe()
# Out:
#               price  registration_year       powerPS    odometer_km  \
# count  5.000000e+04       50000.000000  50000.000000   50000.000000
# mean   9.840044e+03        2005.073280    116.355920  125732.700000
# std    4.811044e+05         105.712813    209.216627   40042.211706
# min    0.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.100000e+03        1999.000000     70.000000  125000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.000000e+08        9999.000000  17700.000000  150000.000000
#
#        registration_month  nrOfPictures    postalCode
# count        50000.000000       50000.0  50000.000000
# mean             5.723360           0.0  50813.627300
# std              3.711984           0.0  25779.747957
# min              0.000000           0.0   1067.000000
# 25%              3.000000           0.0  30451.000000
# ...

# %%
autos.nunique()
# Out:
# dateCrawled           48213
# name                  38754
# seller                    2
# offerType                 2
# price                  2357
# abtest                    2
# vehicleType               8
# registration_year        97
# gearbox                   2
# powerPS                 448
# model                   245
# odometer_km              13
# registration_month       13
# fuelType                  7
# brand                    40
# unrepaired_damage         2
# ad_created               76
# nrOfPictures              1
# postalCode             7014
# lastSeen              39481
# dtype: int64

# %%
autos['odometer_km'].value_counts().head()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# Name: odometer_km, dtype: int64

# %%
autos['price'].value_counts().head()
# Out:
# 0.0       1421
# 500.0      781
# 1500.0     734
# 2500.0     643
# 1200.0     639
# Name: price, dtype: int64

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled           50000 non-null object
# name                  50000 non-null object
# seller                50000 non-null object
# offerType             50000 non-null object
# price                 50000 non-null float64
# abtest                50000 non-null object
# vehicleType           44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# powerPS               50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int64
# registration_month    50000 non-null int64
# fuelType              45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# ad_created            50000 non-null object
# nrOfPictures          50000 non-null int64
# postalCode            50000 non-null int64
# ...

# %%
autos['dateCrawled'].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2016-03-05 14:06:30    0.00002
# 2016-03-05 14:06:40    0.00002
# 2016-03-05 14:07:04    0.00002
# 2016-03-05 14:07:08    0.00002
# 2016-03-05 14:07:21    0.00002
# 2016-03-05 14:07:26    0.00002
# 2016-03-05 14:07:40    0.00002
# 2016-03-05 14:07:45    0.00002
# 2016-03-05 14:08:00    0.00004
# 2016-03-05 14:08:05    0.00004
# 2016-03-05 14:08:27    0.00002
# 2016-03-05 14:08:42    0.00002
# 2016-03-05 14:09:02    0.00004
# 2016-03-05 14:09:05    0.00002
# 2016-03-05 14:09:20    0.00002
# 2016-03-05 14:09:22    0.00002
# 2016-03-05 14:09:38    0.00002
# 2016-03-05 14:09:46    0.00002
# 2016-03-05 14:09:56    0.00002
# 2016-03-05 14:09:57    0.00002
# 2016-03-05 14:09:58    0.00004
# 2016-03-05 14:10:18    0.00002
# 2016-03-05 14:10:20    0.00002
# 2016-03-05 14:10:46    0.00002
# 2016-03-05 14:11:03    0.00002
# 2016-03-05 14:11:05    0.00002
# 2016-03-05 14:11:14    0.00002
# 2016-03-05 14:11:15    0.00002
# 2016-03-05 14:11:25    0.00002
# 2016-03-05 14:11:40    0.00002
# ...

# %%
autos['registration_year'].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
autos = autos[autos['registration_year'].between(1900,2016)]

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  registration_year  \
# 0  privat   Angebot  5000.0  control         bus               2004
# 1  privat   Angebot  8500.0  control   limousine               1997
# 2  privat   Angebot  8990.0     test   limousine               2009
# 3  privat   Angebot  4350.0  control  kleinwagen               2007
# 4  privat   Angebot  1350.0     test       kombi               2003
#
#      gearbox  powerPS   model  odometer_km  registration_month fuelType  \
# ...

# %%
autos.groupby('brand')['price'].mean().sort_values(ascending=False)
# Out:
# brand
# porsche           44553.467577
# citroen           44534.796712
# sonstige_autos    39621.779468
# mercedes_benz     30317.447817
# land_rover        19108.091837
# jeep              11434.750000
# jaguar            11176.197368
# mini              10460.012048
# audi               9093.650036
# bmw                8334.645155
# ford               7263.015811
# volkswagen         6516.457597
# chevrolet          6488.981752
# skoda              6334.919481
# dacia              5915.528455
# kia                5789.351906
# hyundai            5308.539112
# opel               5252.616554
# toyota             5115.333890
# volvo              4757.108108
# nissan             4664.891034
# seat               4296.492554
# mazda              4010.771664
# suzuki             3995.757042
# honda              3988.000000
# alfa_romeo         3984.855346
# subaru             3765.038095
# smart              3542.706587
# mitsubishi         3333.800512
# lancia             3246.365385
# ...

# %%
autos.groupby('brand')['odometer_km'].mean().sort_values(ascending=False)
# Out:
# brand
# saab              144415.584416
# volvo             138355.855856
# rover             135615.384615
# chrysler          133181.818182
# bmw               132434.708554
# alfa_romeo        131399.371069
# mercedes_benz     130860.262009
# audi              129287.780188
# opel              129227.141482
# volkswagen        128730.369062
# renault           128183.817062
# jeep              127546.296296
# peugeot           127136.812412
# mitsubishi        126930.946292
# subaru            124857.142857
# mazda             124745.529574
# ford              124046.837709
# honda             122851.458886
# daewoo            122430.555556
# lancia            122019.230769
# seat              121563.573883
# jaguar            120921.052632
# citroen           119461.883408
# nissan            118572.413793
# land_rover        118010.204082
# fiat              116553.945250
# toyota            115709.515860
# daihatsu          115284.552846
# kia               112434.017595
# ...

# %%
gearbox = {'manuell':'manual','automatik':'auto'}
autos['gearbox'] = autos['gearbox'].map(gearbox)

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  registration_year gearbox  \
# 0  privat   Angebot  5000.0  control         bus               2004  manual
# 1  privat   Angebot  8500.0  control   limousine               1997    auto
# 2  privat   Angebot  8990.0     test   limousine               2009  manual
# 3  privat   Angebot  4350.0  control  kleinwagen               2007    auto
# 4  privat   Angebot  1350.0     test       kombi               2003  manual
#
# ...

# %%
autos['unrepaired_damage'].unique()
# Out:
# array(['nein', nan, 'ja'], dtype=object)

# %%
damage = {'nein':'no','ja':'yes'}
autos['unrepaired_damage']= autos['unrepaired_damage'].map(damage)

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  registration_year gearbox  \
# 0  privat   Angebot  5000.0  control         bus               2004  manual
# 1  privat   Angebot  8500.0  control   limousine               1997    auto
# 2  privat   Angebot  8990.0     test   limousine               2009  manual
# 3  privat   Angebot  4350.0  control  kleinwagen               2007    auto
# 4  privat   Angebot  1350.0     test       kombi               2003  manual
#
# ...

# %%
autos['fuelType'].unique()
# Out:
# array(['lpg', 'benzin', 'diesel', nan, 'cng', 'hybrid', 'elektro',
#        'andere'], dtype=object)

# %%
fuel = {'benzin':'petrol','elektro':'electric','andere':'other','cng':'gas','lpg':'gas','hybrid':'hybrid'}
autos['fuelType'] = autos['fuelType'].map(fuel)

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  registration_year gearbox  \
# 0  privat   Angebot  5000.0  control         bus               2004  manual
# 1  privat   Angebot  8500.0  control   limousine               1997    auto
# 2  privat   Angebot  8990.0     test   limousine               2009  manual
# 3  privat   Angebot  4350.0  control  kleinwagen               2007    auto
# 4  privat   Angebot  1350.0     test       kombi               2003  manual
#
# ...
